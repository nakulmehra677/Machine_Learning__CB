# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('CBCAC103.jpg')

plt.imshow(img)
plt.show()

newimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newimg)
plt.show()

# %%
cv2.imshow('Image', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
